# %%
print("Hello, World!")
name = input("Enter your name: ")
print("Hi,", name)
# Out:
# Hello, World!
# Enter your name: ammu
# Hi, ammu

# %%
age = 25
height = 5.6
name = "Athulya"
is_student = True

print(type(is_student))
# Out:
# <class 'bool'>

# %%
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a ** b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000

# %%
num = 7
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
age = 25
height = 5.6
name = "Athulya"
is_student = True

print(type(name))
# Out:
# <class 'str'>

# %%
x = 18
if x >= 18:
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# You are an adult

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
x = 0
while x < 5:
    print(x)
    x += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
person = {"name": "Athulya", "age": 23, "city": "Kochi"}
print(person["name"])
person["age"] = 24
print(person)
# Out:
# Athulya
# {'name': 'Athulya', 'age': 24, 'city': 'Kochi'}
